# %%
# Required Libraries
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# # Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Load the dataset (assuming it's stored locally as 'titanic.csv')
df = pd.read_csv('data/titanic.csv',index_col='PassengerId')
# Display first few rows to verify data
df.head()
# Out:
#              Unnamed: 0  Survived  Pclass  \
# PassengerId
# 1                     0         0       3
# 2                     1         1       1
# 3                     2         1       3
# 4                     3         1       1
# 5                     4         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# ...

# %%
df.tail()
# Out:
#              Unnamed: 0  Survived  Pclass  \
# PassengerId
# 887                 886         0       2
# 888                 887         1       1
# 889                 888         0       3
# 890                 889         1       1
# 891                 890         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# PassengerId
# 887                             Montvila, Rev. Juozas    male  27.0      0
# 888                      Graham, Miss. Margaret Edith  female  19.0      0
# 889          Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 890                             Behr, Mr. Karl Howell    male  26.0      0
# 891                               Dooley, Mr. Patrick    male  32.0      0
#
#              Parch      Ticket   Fare Embarked
# PassengerId
# 887              0      211536  13.00        S
# 888              0      112053  30.00        S
# 889              2  W./C. 6607  23.45        S
# ...

# %%
# file location directiory 
! dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 461B-E556
#
#  Directory of C:\Users\user\Documents\Data_science_Class\Python
#
# 10/03/2024  06:14 PM    <DIR>          .
# 09/27/2024  06:10 PM    <DIR>          ..
# 10/03/2024  06:03 PM    <DIR>          .ipynb_checkpoints
# 10/03/2024  06:00 PM    <DIR>          data
# 09/24/2024  06:12 PM             3,515 Git_practice.ipynb
# 09/19/2024  05:40 PM             3,453 homejob.ipynb
# 09/18/2024  06:51 PM            16,669 Loop and Functions.ipynb
# 09/25/2024  06:51 PM            31,538 Numpy_class_1.ipynb
# 10/01/2024  05:41 PM           118,384 OLS_python.ipynb
# 09/26/2024  06:40 PM            19,817 Pandas_Tutorial.ipynb
# 09/19/2024  05:07 PM            73,392 python_advanced.ipynb
# 09/11/2024  05:51 PM            34,444 python_basics_day1.ipynb
# 09/16/2024  07:00 PM             7,777 Python_conditions_loop_Functions.ipynb
# 10/03/2024  06:02 PM           146,694 Titanic.ipynb
# ...

# %% [markdown]
# ## Bar plot for Survivval counts

# %%
#Bar plot for survived column: palette for color sets, legend = False for no legends in graph 
plt.figure(figsize=(6,4))
sns.countplot(x='Survived',data=df,hue='Survived',palette='Set1',legend=True)
plt.title('Count of Survived vs Not Survived')
plt.xlabel('Survived (1 = Yes, 0 = No)')
plt.ylabel('Passenger Count')
plt.grid(True)
plt.show()

# %%
#Bar plot for survived column: palette for color sets, legend = False for no legends in graph 
plt.figure(figsize=(6,4))
sns.countplot(x='Survived',data=df,hue='Survived',palette='Set3',legend=False)
plt.title('Count of Survived vs Not Survived')
plt.xlabel('Survived (1 = Yes, 0 = No)')
plt.ylabel('Passenger Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Pie chart for passenger class distribution

# %%
#Pie chart for Pclass 
pclass_counts = df['Pclass'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(pclass_counts, labels=pclass_counts.index, autopct='%1.1f%%', colors=['skyblue', 'orange', 'green'], startangle=180)
plt.title('Passenger Class Distribution')
plt.show()
